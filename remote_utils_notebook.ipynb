# %% [markdown]
# ## Preparation

# %%
# !git clone https://github.com/Roncax/Organ-segmentation-Thesis.git
# Out:
# Cloning into 'Organ-segmentation-Thesis'...
# remote: Enumerating objects: 587, done.
# remote: Counting objects: 100% (587/587), done.
# remote: Compressing objects: 100% (395/395), done.
# remote: Total 587 (delta 262), reused 503 (delta 182), pack-reused 0
# Receiving objects: 100% (587/587), 39.51 MiB | 18.62 MiB/s, done.
# Resolving deltas: 100% (262/262), done.

# %%
# !pip3 install nnunet~=1.6.6 albumentations~=0.5.2 scikit-image~=0.18.1 telegram_send segmentation_models_pytorch

# %%
# %cd /notebooks/Organ-segmentation-Thesis

# %%
from zipfile import ZipFile
with ZipFile('raw_data_segthor.zip', 'r') as zf:
    zf.extractall('')

# %%
# !python /notebooks/Organ-segmentation-Thesis/OaR_segmentation/db_loaders/conversion_main.py

# %%
from shutil import make_archive
for i in range (10072, 10073):
    number = i
    make_archive(f'/notebooks/Organ-segmentation-Thesis/data/checkpoints_segmentation/{number}', 'zip', 
                 root_dir=f'/notebooks/Organ-segmentation-Thesis/data/checkpoints_segmentation/{number}')

# %% [markdown]
# ## Main

# %%
# !python /notebooks/Organ-segmentation-Thesis/OaR_segmentation/training/train_segmentation.py
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# 2021-09-25 22:46:54.647945: Experiment 10061
# 2021-09-25 22:46:54.648798: Organ(s) ['Esophagus']
# 2021-09-25 22:46:54.648882: Model SegNet
# 2021-09-25 22:46:54.682523:
# epoch:  0
# 2021-09-25 22:48:16.107140: train loss : 0.4054
# Validation epoch 0: 100%|█████████▉| 765/766 [00:10<00:00, 89.96batch/s, loss=0]2021-09-25 22:48:26.327055: validation loss: 0.3502
# No handles with labels found to put in legend.
# 2021-09-25 22:48:41.762690: my real validation loss is 0.9904239342165916
# 2021-09-25 22:48:41.763114: lr is now (scheduler) 0.001
# 2021-09-25 22:48:41.763212: current best_val_eval_criterion_MA is 0.99040
# ...
